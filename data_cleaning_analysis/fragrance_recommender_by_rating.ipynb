# %% [markdown]
# <a href="https://colab.research.google.com/github/abiflynn/BeautyBOT/blob/main/data_cleaning_analysis/fragrance_recommender_by_rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Perfume Recommender

# %% [markdown]
# ### Import/ Display / Connect Drive

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option("display.max_colwidth", 1000)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Top Womens Perfumes (By Item Rating)

# %%
def top_perfumes_women(n):

    #filter only to womens perfume
    perfume_women = perfume[perfume["department"] == "Women"]

    #sort by item rating to n values 
    top_perfumes = perfume_women.sort_values(by='item_rating', ascending=False)[["brand", "name", "ml", "scents", "item_rating"]][:n]

    #return top n movies as a dataframe
    return top_perfumes

# %%
top_perfumes_women(10)
# Out:
#                         brand            name   ml   scents  item_rating
# 517                J.CASANOVA         Pandora   50   Fruity          5.0
# 195                J.CASANOVA         Pandora  100   Floral          5.0
# 200                   LACOSTE   Touch Of Pink   90   Floral          5.0
# 201                      Dior          Addict  100   Floral          5.0
# 202                  BURBERRY  My Burberry Bl   90   Floral          5.0
# 700           Dolce & Gabbana      Pour Femme  100   Floral          5.0
# 206                  Benetton             Hot  100   Fruity          5.0
# 360              Estee Lauder     White Linen   60  Arabian          5.0
# 210  Sedr Al-Khaleej Perfumes      Love Touch  100    Fresh          5.0
# 708           Elizabeth Arden        Red Door  100   Floral          5.0

# %% [markdown]
# ### Top Mens Aftershave (By Item Rating)

# %%
def top_aftershave_men(n):

    #filter only to womens perfume
    aftershave_men = perfume[perfume["department"] == "Men"]

    #sort by item rating to n values 
    top_aftershaves = aftershave_men.sort_values(by='item_rating', ascending=False)[:n]

    #return top n movies as a dataframe
    return top_aftershaves

# %%
top_aftershave_men(5)
# Out:
#      Unnamed:0         brand              name  old_price  new_price   ml concentration department  scents                                                    base_note                                       middle_note  item_rating       seller  seller_rating num_seller_ratings
# 0            0  PACO RABANNE   1 Million Lucky     395.00     244.55  100           EDT        Men   Woody                               Oakmoss, Patchouli and Vetiver  Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0         noon            4.2              98.1K
# 466        466  Remy Marquis            Shalis      50.35      50.35  100           EDP        Men  Fruity                               Nutmeg, Oakmoss And Sandalwood                                Lavender And Basil          5.0  VIP.PARFUME            3.5                244
# ...

# %%
perfume
# Out:
#       Unnamed:0            brand                      name  old_price  new_price   ml concentration department   scents                                    base_note                                       middle_note  item_rating                                                       seller  seller_rating num_seller_ratings
# 0             0     PACO RABANNE           1 Million Lucky      395.0     244.55  100           EDT        Men    Woody               Oakmoss, Patchouli and Vetiver  Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0                                                         noon            4.2              98.1K
# 1             1  Roberto Cavalli         Paradiso Assoluto      415.0     107.95   50           EDP      Women   Floral            Vanilla, Sandalwood And Patchouli                         Wild Jasmine and Red Lily          4.8                                                         noon            4.2              98.1K
# ...

# %%
perfume.head()
